# %%
import matplotlib as mpl
# %matplotlib inline

# %%
mpl.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(3, 2, ".")

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3, 2, ".")
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png'/>
# Out:
# <img src = 'test.png'/>

# %%
import numpy as np

# %%
x= np.arange(1,9,1)
y=x

plt.figure()
plt.scatter(x,y)

# %%
x = np.arange(1, 9, 1)
y = x
colors = ['green']*(len(x)-1)
colors.append('red')
plt.figure()
plt.scatter(x, y, s=100, c=colors)

# %%
zip_generator = zip(np.arange(1,5,1),np.arange(6,10,1))

# list(zip_generator)

# %%
# zip_generator = zip(np.arange(1,5,1),np.arange(6,10,1))
x, y = zip(*zip_generator)
print(x)
print(y)
# Out:
# (1, 2, 3, 4)
# (6, 7, 8, 9)

# %%
plt.figure()
plt.scatter(x[: 2], y[: 2], c='red',label="Tall")
plt.scatter(x[2:], y[2:], c='blue', label='short')
plt.xlabel("child kicked a ball")
plt.ylabel("Ball kicking and grade relation")
plt.title("Relation")

# %%
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
linear = np.arange(1, 10, 1)
quad = linear **2
plt.figure()
plt.plot(linear, '--r', quad, '-o')

plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('title')

plt.legend(['linear', 'quad'])

# %%
plt.gca().fill_between(range(len(linear)),linear, quad, facecolors='green', alpha = 0.25)

# %%
import pandas as pd

# %%
plt.figure()
observation = np.arange('2017-01-01', '2017-01-10', dtype='datetime64[D]')
observation = list(map(pd.to_datetime, observation))
plt.plot(observation,linear, '-o',observation, quad, '-o')
# Out:
# [<matplotlib.lines.Line2D at 0x7fc074dadcf8>,
#  <matplotlib.lines.Line2D at 0x7fc074d63c18>]

# %%
x = plt.gca().xaxis

for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %%
plt.figure()
xvals = range(len(linear))
plt.bar(xvals,linear,width = 0.3)

new_xvals = []
for item in xvals:
    new_xvals.append(item+0.3)
plt.bar(new_xvals,quad,width = 0.3, color = 'red')

from random import randint

linear_err = [randint(0, 15) for x in range(len(linear))]
plt.bar(xvals, linear, yerr = linear_err,width = 0.3)
# Out:
# <Container object of 9 artists>

# %%
plt.subplot(2,2,1)
plt.plot(linear, '-o')
plt.subplot(2,2,2)
plt.scatter(linear,linear)
plt.subplot(2,2,3)
plt.scatter(linear,linear)

# %% [markdown]
# ## Histrograms

# %%
plt.figure()
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0,size=sample_size)
    axs[n].hist(sample, bins=100)

# %%
plt.figure()
Y = np.random.normal(loc=0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)

# %%
import matplotlib.gridspec as gridspec

# %%
plt.figure()
gspec = gridspec.GridSpec(3, 3)
top = plt.subplot(gspec[0,1: ])
side = plt.subplot(gspec[1:, 0])
right = plt.subplot(gspec[1:,1:])

right.scatter(X,Y)
top.hist(X,bins=1000)
s=side.hist(Y,bins=1000,orientation='horizontal')
